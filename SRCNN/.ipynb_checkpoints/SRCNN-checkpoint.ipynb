# %%
# !python /content/drive/MyDrive/SRCNN/train.py --train-file "/content/drive/MyDrive/SRCNN/example/example.h5" \
                --eval-file "/content/drive/MyDrive/SRCNN/exampleEval/exampleEval.h5" \
                --outputs-dir "/content/drive/MyDrive/SRCNN/outputs/Example" \
                --scale 2 \
                --lr 1e-4 \
                --batch-size 16 \
                --num-epochs 10 \
                --num-workers 2 \
                --seed 123
# Out:
# epoch: 0/9: 100% 43200/43200 [01:23<00:00, 518.75it/s, loss=0.003832]
# eval psnr: 62.24
# epoch: 1/9: 100% 43200/43200 [01:19<00:00, 545.81it/s, loss=0.000001]
# eval psnr: 60.58
# epoch: 2/9: 100% 43200/43200 [01:23<00:00, 518.32it/s, loss=0.000003]
# eval psnr: 53.48
# epoch: 3/9: 100% 43200/43200 [01:20<00:00, 534.43it/s, loss=0.000004]
# eval psnr: 59.79
# epoch: 4/9: 100% 43200/43200 [01:23<00:00, 520.33it/s, loss=0.000003]
# eval psnr: 47.18
# epoch: 5/9: 100% 43200/43200 [01:20<00:00, 534.39it/s, loss=0.000003]
# eval psnr: 48.90
# epoch: 6/9: 100% 43200/43200 [01:20<00:00, 534.21it/s, loss=0.000003]
# eval psnr: 55.35
# epoch: 7/9: 100% 43200/43200 [01:20<00:00, 536.62it/s, loss=0.000003]
# eval psnr: 58.90
# epoch: 8/9: 100% 43200/43200 [01:17<00:00, 558.79it/s, loss=0.000003]
# eval psnr: 61.14
# epoch: 9/9: 100% 43200/43200 [01:20<00:00, 534.73it/s, loss=0.000003]
# eval psnr: 60.88
# best epoch: 0, psnr: 62.24

# %%
# !python /content/drive/MyDrive/SRCNN/prepare.py --images-dir "/content/drive/MyDrive/SRCNN/example" --output-path "/content/drive/MyDrive/SRCNN/example/example.h5"
# Out:
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000001.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000002.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000003.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000004.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000005.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000006.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000007.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000008.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000009.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000010.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000011.tif
# Converting image /content/drive/MyDrive/SRCNN/example/Copia de Img000012.tif
# ...

# %%
# !python /content/drive/MyDrive/SRCNN/test.py --weights-file "/content/drive/MyDrive/SRCNN/testExample/srcnn_x2.pth" \
               --image-file "/content/drive/MyDrive/SRCNN/testExample/Copia de Img000001.tif" \
               --scale 2
# Out:
# PSNR: 58.66
